# %% [markdown]
# <a href="https://colab.research.google.com/github/HFAJIR/GenAI_ML_Bootcamp/blob/main/Week5/Day1/Daily_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Task 1. Data Preparation:
# --- Generate synthetic temperature data ---
temps = np.random.uniform(low=-5, high=35, size=(10, 12))

# City names
cities = [f"City_{i+1}" for i in range(10)]

# Month names
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# --- Create DataFrame ---
df = pd.DataFrame(temps, index=cities, columns=months)

df.head()
# Out:
#               Jan        Feb        Mar        Apr        May        Jun  \
# City_1  34.739406  19.870112  -0.795192  34.817526  15.286504   9.780717
# City_2  -3.110696  22.939560  31.144511  10.636498   2.704525  28.474287
# City_3  26.244369  -4.664149   3.379286  19.472494  32.092781   6.181601
# City_4  -1.698734  21.366464   5.498399  33.996951   5.807720  16.326195
# City_5  15.208442  11.351186  13.653544  12.192161  16.458249  -4.102007
#
#               Jul        Aug        Sep        Oct        Nov        Dec
# City_1  21.860432   3.698352   8.599703  -4.021368  16.018503  27.529234
# City_2  -1.964962   9.725951   3.177966   1.952420  21.895213  21.879113
# City_3   5.921632  32.820501  29.956146  -0.416351  32.081654  31.709711
# City_4  24.478092  11.488871  21.744104  14.823680  21.283413   9.252411
# City_5   2.039019   5.925768   0.803333   8.136402  -1.091907  15.939341

# %%
#task 2. Data Analysis:
# Annual average temperature per city
annual_averge = df.mean(axis=1)

# Identify hottest & coldest cities
hottest_city = annual_averge.idxmax()
coldest_city = annual_averge.idxmin()

annual_averge, hottest_city, coldest_city
# Out:
# (City_1     15.615327
#  City_2     12.454532
#  City_3     17.898306
#  City_4     15.363964
#  City_5      8.042794
#  City_6     11.131393
#  City_7     17.504791
#  City_8     14.803908
#  City_9      9.424304
#  City_10    16.207288
#  dtype: float64,
#  'City_3',
#  'City_5')

# %%
#task 3. Data Visualization:
plt.figure(figsize=(14, 6))
for city in df.index:
    if city == hottest_city:
        plt.plot(df.columns, df.loc[city], marker="o", linewidth=3, label=f"{city} (Hottest)",color ='red',alpha=0.2)
    elif city == coldest_city:
        plt.plot(df.columns, df.loc[city], marker="s", linewidth=3, label=f"{city} (Coldest)",color ='blue',alpha=0.2)
    else:
        plt.plot(df.columns, df.loc[city], label = city)
plt.title("Monthly Temperature Trends for Each City")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.legend(loc="lower left")
#plt.tight_layout()
plt.show()
